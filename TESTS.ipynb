# %%
from pydantic import BaseModel, Field
from langchain_ollama.chat_models import ChatOllama
from langchain.prompts import PromptTemplate

# %%
llm = ChatOllama(model="cow/gemma2_tools:2b")

# %%
class JokeChecker():
    """ Joke checker , parse subject and punchline"""
    subject:str = Field(description="Subject of the joke")
    punchline: str = Field(description="Punchline of the joke") 
    joke: str = Field(description="Generated joke generated by llm")

# %%
llm_so = llm.with_structured_output(JokeChecker)

# %%
llm_so.invoke("Tell me a joke")
# Out:
# {'punchline': 'Because they make up everything!',
#  'subject': "Why don't scientists trust atoms? "}

# %%
from typing import List

class Actor(BaseModel):
    name: str = Field(description="name of an actor")
    film_names: List[str] = Field(description="list of names of films they starred in")

# %%
llm_so = llm.with_structured_output(Actor)

# %%
llm_so.invoke("Generate the filmography for a random actor.")
# Out:
# Actor(name='Leonardo DiCaprio', film_names=['Inception', 'The Wolf of Wall Street', 'Titanic', 'Django Unchained', 'The Aviator'])
